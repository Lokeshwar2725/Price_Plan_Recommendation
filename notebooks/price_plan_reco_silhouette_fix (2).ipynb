# %% [markdown]
# # 📊 Price Plan Recommendation — High-Silhouette & Safe Billing (IPYNB)

# %% [markdown]
# This notebook is tuned to:
# - Improve **silhouette** using **MinMaxScaler** and optional **PCA**
# - Prevent **negative bills** via share normalization and safe clipping
# - Deliver **Top‑3 plan recommendations** with ≤25 plans

# %% [markdown]
# ## 0) Setup & Load

# %%
import pandas as pd
import numpy as np
from pathlib import Path

DATA_PATH = Path(r"C:\Users\look4\Price_Plan_Recommendation\data\raw\cdr_dataset.csv")
df = pd.read_csv(DATA_PATH).copy()

def normalize(col: str) -> str:
    return col.strip().lower().replace(" ", "_").replace("-", "_").replace(".", "_")
df.rename(columns={c: normalize(c) for c in df.columns}, inplace=True)

print("Loaded shape:", df.shape)
df.head(3)
# Out:
# Loaded shape: (101174, 17)
#   phone_number  account_length  vmail_message  day_mins  day_calls  \
# 0     382-4657             128             25     265.1        110
# 1     371-7191             107             26     161.6        123
# 2     358-1921             137              0     243.4        114
#
#    day_charge  eve_mins  eve_calls  eve_charge  night_mins  night_calls  \
# 0       45.07     197.4         99       16.78       244.7           91
# 1       27.47     195.5        103       16.62       254.4          103
# 2       41.38     121.2        110       10.30       162.6          104
#
#    night_charge  intl_mins  intl_calls  intl_charge  custserv_calls  churn
# 0         11.01       10.0           3         2.70               1  False
# 1         11.45       13.7           3         3.70               1  False
# 2          7.32       12.2           5         3.29               0  False

# %% [markdown]
# ## 1) Preprocess & Feature Engineering

# %%
aliases = {
    "account_length": ["account_length"],
    "vmail_message": ["vmail_message","voice_mail_messages","voicemail_message"],
    "international_plan": ["international_plan","intl_plan"],
    "voice_mail_plan": ["voice_mail_plan","voicemail_plan"],
    "custserv_calls": ["custserv_calls","customer_service_calls"],
    "day_mins": ["day_mins","total_day_minutes"],
    "eve_mins": ["eve_mins","total_eve_minutes"],
    "night_mins": ["night_mins","total_night_minutes"],
    "intl_mins": ["intl_mins","total_intl_minutes"],
    "day_calls": ["day_calls","total_day_calls"],
    "eve_calls": ["eve_calls","total_eve_calls"],
    "night_calls": ["night_calls","total_night_calls"],
    "intl_calls": ["intl_calls","total_intl_calls"],
    "day_charge": ["day_charge","total_day_charge"],
    "eve_charge": ["eve_charge","total_eve_charge"],
    "night_charge": ["night_charge","total_night_charge"],
    "intl_charge": ["intl_charge","total_intl_charge"],
}

def pick(name):
    for c in aliases.get(name, []):
        if c in df.columns:
            return c
    return None

canonical_map = {k: pick(k) for k in aliases.keys()}

mins_cols   = [canonical_map[c] for c in ["day_mins","eve_mins","night_mins","intl_mins"] if canonical_map.get(c)]
calls_cols  = [canonical_map[c] for c in ["day_calls","eve_calls","night_calls","intl_calls"] if canonical_map.get(c)]
charge_cols = [canonical_map[c] for c in ["day_charge","eve_charge","night_charge","intl_charge"] if canonical_map.get(c)]

if mins_cols:   df["total_mins"]   = df[mins_cols].sum(axis=1)
if calls_cols:  df["total_calls"]  = df[calls_cols].sum(axis=1)
if charge_cols: df["total_charge"] = df[charge_cols].sum(axis=1)

# Shares
if "total_mins" in df.columns:
    for part in ["day","eve","night","intl"]:
        col = canonical_map.get(f"{part}_mins")
        if col:
            df[f"{part}_mins_share"] = df[col] / df["total_mins"].replace(0, np.nan)

# Avg mins per call
if {"total_mins","total_calls"}.issubset(df.columns):
    df["avg_mins_per_call"] = df["total_mins"] / df["total_calls"].replace(0, np.nan)

print("Engineered shape:", df.shape)
df.head(3)
# Out:
# Engineered shape: (101174, 25)
#   phone_number  account_length  vmail_message  day_mins  day_calls  \
# 0     382-4657             128             25     265.1        110
# 1     371-7191             107             26     161.6        123
# 2     358-1921             137              0     243.4        114
#
#    day_charge  eve_mins  eve_calls  eve_charge  night_mins  ...  \
# 0       45.07     197.4         99       16.78       244.7  ...
# 1       27.47     195.5        103       16.62       254.4  ...
# 2       41.38     121.2        110       10.30       162.6  ...
#
#    custserv_calls  churn  total_mins  total_calls  total_charge  \
# 0               1  False       717.2          303         75.56
# 1               1  False       625.2          332         59.24
# 2               0  False       539.4          333         62.29
#
#    day_mins_share  eve_mins_share  night_mins_share  intl_mins_share  \
# 0        0.369632        0.275237          0.341188         0.013943
# 1        0.258477        0.312700          0.406910         0.021913
# 2        0.451242        0.224694          0.301446         0.022618
#
#    avg_mins_per_call
# 0           2.366997
# 1           1.883133
# 2           1.619820
#
# [3 rows x 25 columns]

# %% [markdown]
# ## 2) Data Cleaning (duplicates, missing, outliers)

# %%
before = len(df)

# Keep only unique phone numbers (drop duplicates)
if "phone_number" in df.columns:
    df = df.drop_duplicates(subset=["phone_number"], keep="first")  # keep first occurrence
    print(f"Removed duplicates based on phone_number: {before - len(df)} rows")
else:
    df = df.drop_duplicates()
    print(f"Removed exact duplicate rows: {before - len(df)}")

# Fill missing values with 0
df = df.fillna(0)

# Remove outliers (IQR method) from key usage columns
for col in ["total_mins", "total_calls", "total_charge"]:
    if col in df.columns:
        Q1, Q3 = df[col].quantile(0.25), df[col].quantile(0.75)
        IQR = Q3 - Q1
        lower, upper = Q1 - 1.5 * IQR, Q3 + 1.5 * IQR
        before_out = len(df)
        df = df[(df[col] >= lower) & (df[col] <= upper)]
        print(f"Removed {before_out - len(df)} outliers from {col}")

print("Final dataset shape:", df.shape)
# Out:
# Removed duplicates based on phone_number: 93707 rows
# Removed 0 outliers from total_mins
# Removed 400 outliers from total_calls
# Removed 0 outliers from total_charge
# Final dataset shape: (7067, 25)

# %% [markdown]
# ## 3) Scaling (MinMax) + Optional PCA

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import PCA

features = [
    canonical_map.get("account_length"),
    canonical_map.get("vmail_message"),
    "total_mins","total_calls",
    "day_mins_share","eve_mins_share","night_mins_share","intl_mins_share",
    canonical_map.get("custserv_calls"),
]
features = [f for f in features if f is not None]
X = df[features].astype(float).fillna(0)

share_cols = ["day_mins_share","eve_mins_share","night_mins_share","intl_mins_share"]
if all(c in X.columns for c in share_cols):
    S = X[share_cols].sum(axis=1).replace(0, 1.0)
    for c in share_cols:
        X[c] = np.clip(X[c] / S, 0, 1)

scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

USE_PCA = True
PCA_COMPONENTS = 6
if USE_PCA:
    pca = PCA(n_components=PCA_COMPONENTS, random_state=42)
    X_for_cluster = pca.fit_transform(X_scaled)
    print("PCA variance:", np.round(pca.explained_variance_ratio_, 3))
else:
    pca = None
    X_for_cluster = X_scaled
# Out:
# PCA variance: [0.418 0.205 0.126 0.068 0.064 0.053]

# %% [markdown]
# ## 4) Silhouette Scan

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
import matplotlib.pyplot as plt

sil_scores = {}
for k in range(4, 11):
    km = KMeans(n_clusters=k, random_state=42, n_init=20)
    labels = km.fit_predict(X_for_cluster)
    sil_scores[k] = round(silhouette_score(X_for_cluster, labels), 3)

print("Silhouette scores:", sil_scores)

plt.plot(list(sil_scores.keys()), list(sil_scores.values()), marker='o')
plt.title("Silhouette vs k )")
plt.xlabel("k")
plt.ylabel("Silhouette")
plt.show()
# Out:
# c:\Users\look4\anaconda3\Lib\site-packages\joblib\externals\loky\backend\context.py:136: UserWarning: Could not find the number of physical cores for the following reason:
# [WinError 2] The system cannot find the file specified
# Returning the number of logical cores instead. You can silence this warning by setting LOKY_MAX_CPU_COUNT to the number of cores you want to use.
#   warnings.warn(
#   File "c:\Users\look4\anaconda3\Lib\site-packages\joblib\externals\loky\backend\context.py", line 257, in _count_physical_cores
#     cpu_info = subprocess.run(
#                ^^^^^^^^^^^^^^^
#   File "c:\Users\look4\anaconda3\Lib\subprocess.py", line 548, in run
#     with Popen(*popenargs, **kwargs) as process:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\look4\anaconda3\Lib\subprocess.py", line 1026, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#   File "c:\Users\look4\anaconda3\Lib\subprocess.py", line 1538, in _execute_child
#     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Silhouette scores: {4: 0.429, 5: 0.385, 6: 0.402, 7: 0.286, 8: 0.269, 9: 0.257, 10: 0.266}

# %% [markdown]
# ## 5) Final Kmeans

# %%
AUTO_PICK_BEST = False
best_k = max(sil_scores, key=sil_scores.get) if AUTO_PICK_BEST else 6
print("Using k =", best_k)

kmeans = KMeans(n_clusters=best_k, random_state=42, n_init=20)
df["Cluster"] = kmeans.fit_predict(X_for_cluster)

final_sil = silhouette_score(X_for_cluster, df["Cluster"])
print(f"Silhouette (final, k={best_k}): {final_sil:.3f}")
# Out:
# Using k = 6
# Silhouette (final, k=6): 0.402

# %% [markdown]
# ## 6) Profiling

# %%
## Cluster profiling for k=6
profile_cols = [
    "total_mins","total_calls","total_charge",
    "day_mins_share","eve_mins_share","night_mins_share","intl_mins_share",
    "avg_mins_per_call"
]
cluster_profile = df.groupby("Cluster")[profile_cols].mean().round(3)
sizes = df["Cluster"].value_counts().sort_index().rename("size")
cluster_profile = pd.concat([sizes, cluster_profile], axis=1)

print("Cluster profiles (k=6):")
cluster_profile
# Out:
# Cluster profiles (k=6):
#          size  total_mins  total_calls  total_charge  day_mins_share  \
# Cluster
# 0        3355     629.340      337.392        61.007           0.305
# 1         854    1370.473      736.317       118.302           0.315
# 2         922    1355.684      723.034       116.097           0.313
# 3         340    1370.241      737.668       118.489           0.317
# 4         356    1370.143      708.365       120.137           0.313
# 5        1240     626.437      336.732        61.011           0.304
#
#          eve_mins_share  night_mins_share  intl_mins_share  avg_mins_per_call
# Cluster
# 0                 0.338             0.338            0.019              1.993
# 1                 0.334             0.331            0.020              2.186
# 2                 0.330             0.336            0.021              2.250
# 3                 0.334             0.329            0.020              2.169
# 4                 0.331             0.335            0.021              2.332
# 5                 0.339             0.338            0.018              1.991

# %% [markdown]
# ## 7) Plan Catalog

# %%
def mk_plan(name, monthly_rental, local_rate, night_rate, eve_rate, intl_rate,
            free_day=0, free_night=0, free_eve=0, free_intl=0):
    return {
        "plan_name": name,
        "monthly_rental": monthly_rental,
        "rate_local_day": local_rate,
        "rate_local_eve": eve_rate,
        "rate_local_night": night_rate,
        "rate_intl": intl_rate,
        "free_day": free_day,
        "free_eve": free_eve,
        "free_night": free_night,
        "free_intl": free_intl,
    }

catalog_specs = [
    # Light Talkers (Cluster ~low mins)
    ("Lite Voice 99",      99, 0.20, 0.12, 0.12, 0.35, 100, 50, 50, 0),
    ("Lite Value 149",    149, 0.18, 0.10, 0.10, 0.32, 200,100,100,0),

    # Day Users
    ("Day Saver 249",     249, 0.15, 0.10, 0.09, 0.28, 500,100,100,0),
    ("Day Pro 349",       349, 0.14, 0.10, 0.09, 0.27, 800,150,150,0),

    # Night Owls
    ("Night Owl 199",     199, 0.18, 0.05, 0.12, 0.32,  50,800,100,0),
    ("Midnight Max 299",  299, 0.17, 0.00, 0.12, 0.30, 100,1500,200,0),

    # Balanced Users
    ("All-Rounder 299",   299, 0.16, 0.08, 0.08, 0.28, 300,300,300,10),
    ("All-Rounder Pro 399",399,0.15, 0.08, 0.08, 0.27, 400,400,400,20),

    # Heavy Talkers
    ("Unlimited Talk 399",399, 0.14, 0.07, 0.07, 0.28, 900,600,600,0),
    ("Ultra Unlimited 499",499,0.13, 0.06, 0.07, 0.26,1200,800,800,0),

    # Global Users
    ("Global Saver 399",  399, 0.16, 0.08, 0.08, 0.23, 300,200,200,50),
    ("Global Connect 599",599, 0.15, 0.08, 0.08, 0.20, 500,300,300,100),
]

catalog = [mk_plan(*spec) for spec in catalog_specs]
catalog_df = pd.DataFrame(catalog)

print("Total plans:", len(catalog_df))
catalog_df
# Out:
# Total plans: 12
#               plan_name  monthly_rental  rate_local_day  rate_local_eve  \
# 0         Lite Voice 99              99            0.20            0.12
# 1        Lite Value 149             149            0.18            0.10
# 2         Day Saver 249             249            0.15            0.09
# 3           Day Pro 349             349            0.14            0.09
# 4         Night Owl 199             199            0.18            0.12
# 5      Midnight Max 299             299            0.17            0.12
# 6       All-Rounder 299             299            0.16            0.08
# 7   All-Rounder Pro 399             399            0.15            0.08
# 8    Unlimited Talk 399             399            0.14            0.07
# 9   Ultra Unlimited 499             499            0.13            0.07
# 10     Global Saver 399             399            0.16            0.08
# 11   Global Connect 599             599            0.15            0.08
#
#     rate_local_night  rate_intl  free_day  free_eve  free_night  free_intl
# 0               0.12       0.35       100        50          50          0
# 1               0.10       0.32       200       100         100          0
# 2               0.10       0.28       500       100         100          0
# 3               0.10       0.27       800       150         150          0
# 4               0.05       0.32        50       100         800          0
# 5               0.00       0.30       100       200        1500          0
# 6               0.08       0.28       300       300         300         10
# 7               0.08       0.27       400       400         400         20
# 8               0.07       0.28       900       600         600          0
# 9               0.06       0.26      1200       800         800          0
# 10              0.08       0.23       300       200         200         50
# 11              0.08       0.20       500       300         300        100

# %% [markdown]
# ## 8) Billing and Recommendation

# %%
# =============================
# Enhanced Billing + Recommendations
# =============================
import numpy as np
import pandas as pd

def safe_normalize_shares(row):
    """Safely normalize usage shares"""
    keys = ["day_mins_share", "eve_mins_share", "night_mins_share", "intl_mins_share"]
    vals = [max(0, float(row.get(k, 0))) for k in keys]
    s = sum(vals)
    return dict(zip(keys, [0.25, 0.25, 0.25, 0.25] if s <= 0 else [v/s for v in vals]))

def estimate_bill(row, plan):
    """Calculate estimated bill with safeguards"""
    try:
        total = max(row.get("total_mins", 0), 0)
        shares = safe_normalize_shares(row)
        
        # Calculate minutes for each period
        d = shares["day_mins_share"] * total
        e = shares["eve_mins_share"] * total
        n = shares["night_mins_share"] * total
        intl = shares["intl_mins_share"] * total
        
        # Calculate billable minutes (after free minutes)
        d_bill = max(d - float(plan["free_day"]), 0)
        e_bill = max(e - float(plan["free_eve"]), 0)
        n_bill = max(n - float(plan["free_night"]), 0)
        i_bill = max(intl - float(plan["free_intl"]), 0)
        
        # Calculate variable charges
        variable = (
            d_bill * float(plan["rate_local_day"]) +
            e_bill * float(plan["rate_local_eve"]) +
            n_bill * float(plan["rate_local_night"]) +
            i_bill * float(plan["rate_intl"])
        )
        
        return round(float(plan["monthly_rental"]) + variable, 2)
    except Exception as e:
        print(f"Warning: Billing calculation error - {str(e)}")
        return float(plan["monthly_rental"])

def calculate_plan_suitability(row, plan):
    """Calculate plan suitability score (0-1)"""
    try:
        # Get usage patterns
        total = max(row.get("total_mins", 0), 0)
        shares = safe_normalize_shares(row)
        
        # Time distribution match (40%)
        time_match = 1 - sum([
            abs(shares["day_mins_share"] - (plan["free_day"] / (plan["free_day"] + plan["free_eve"] + plan["free_night"]))),
            abs(shares["eve_mins_share"] - (plan["free_eve"] / (plan["free_day"] + plan["free_eve"] + plan["free_night"]))),
            abs(shares["night_mins_share"] - (plan["free_night"] / (plan["free_day"] + plan["free_eve"] + plan["free_night"])))
        ]) / 2
        
        # Usage volume match (30%)
        total_free = plan["free_day"] + plan["free_eve"] + plan["free_night"]
        volume_match = min(1.0, total_free / max(total, 1))
        
        # Special features match (30%)
        special_score = 0.0
        if shares["intl_mins_share"] > 0.05 and plan["free_intl"] > 0:
            special_score += 0.5
        if total > 800 and total_free > 800:
            special_score += 0.5
            
        # Final weighted score
        final_score = (
            0.4 * time_match +
            0.3 * volume_match +
            0.3 * special_score
        )
        
        return round(float(np.clip(final_score, 0, 1)), 3)
    except Exception as e:
        print(f"Warning: Suitability calculation error - {str(e)}")
        return 0.0

def recommend_plans(row, catalog_df, n_recommendations=3):
    """Generate diverse plan recommendations"""
    try:
        recommendations = []
        
        # Calculate scores for all plans
        for _, plan in catalog_df.iterrows():
            monthly_cost = estimate_bill(row, plan)
            suitability = calculate_plan_suitability(row, plan)
            
            # Get plan category and price tier
            category = plan["plan_name"].split()[0]
            price_tier = (
                'Budget' if plan["monthly_rental"] < 250 
                else 'Premium' if plan["monthly_rental"] > 400 
                else 'Standard'
            )
            
            recommendations.append({
                "plan_name": plan["plan_name"],
                "category": category,
                "price_tier": price_tier,
                "monthly_cost": monthly_cost,
                "suitability": suitability,
                "final_score": round(0.5 * (1 - monthly_cost/1000) + 0.5 * suitability, 3)
            })
        
        # Convert to DataFrame for easier handling
        recs_df = pd.DataFrame(recommendations)
        
        # Select diverse recommendations
        final_recs = []
        categories_used = set()
        
        # First get the absolute best match
        best = recs_df.nlargest(1, "final_score").iloc[0]
        final_recs.append(best)
        categories_used.add(best["category"])
        
        # Then get plans from different categories
        remaining = recs_df[~recs_df["category"].isin(categories_used)]
        while len(final_recs) < n_recommendations and not remaining.empty:
            next_best = remaining.nlargest(1, "final_score").iloc[0]
            final_recs.append(next_best)
            categories_used.add(next_best["category"])
            remaining = recs_df[~recs_df["category"].isin(categories_used)]
        
        # If we still need more, take best remaining
        remaining = recs_df[~recs_df["plan_name"].isin([r["plan_name"] for r in final_recs])]
        while len(final_recs) < n_recommendations and not remaining.empty:
            next_best = remaining.nlargest(1, "final_score").iloc[0]
            final_recs.append(next_best)
            remaining = remaining[remaining["plan_name"] != next_best["plan_name"]]
        
        return final_recs
        
    except Exception as e:
        print(f"Warning: Recommendation error - {str(e)}")
        return []

# Generate recommendations for all customers
recs = []
for idx, row in df.iterrows():
    try:
        recommendations = recommend_plans(row, catalog_df)
        phone = str(row[phone_col]).strip() if phone_col else None
        
        for rank, rec in enumerate(recommendations, 1):
            recs.append({
                "index": idx,
                "phone_number": phone,
                "cluster": int(row["Cluster"]),
                "plan_name": rec["plan_name"],
                "category": rec["category"],
                "estimated_cost": round(rec["monthly_cost"], 2),
                "suitability": rec["suitability"],
                "final_score": rec["final_score"],
                "rank": rank
            })
    except Exception as e:
        print(f"Warning: Error processing customer {idx} - {str(e)}")
        continue

# Create recommendations DataFrame
recs_df = pd.DataFrame(recs)

# Analyze plan distribution
print("\nPlan Distribution Analysis:")
print("-" * 50)
plan_dist = recs_df["plan_name"].value_counts()
print("\nRecommendations per plan:")
print(plan_dist)

# Visualize distribution
plt.figure(figsize=(12, 6))
plan_dist.plot(kind='bar')
plt.title('Distribution of Recommended Plans')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# Display sample recommendations
print("\nSample Recommendations:")
display(recs_df.head(10))
# Out:
# Warning: Error processing customer 0 - name 'phone_col' is not defined
# Warning: Error processing customer 1 - name 'phone_col' is not defined
# Warning: Error processing customer 2 - name 'phone_col' is not defined
# Warning: Error processing customer 3 - name 'phone_col' is not defined
# Warning: Error processing customer 4 - name 'phone_col' is not defined
# Warning: Error processing customer 5 - name 'phone_col' is not defined
# Warning: Error processing customer 6 - name 'phone_col' is not defined
# Warning: Error processing customer 7 - name 'phone_col' is not defined
# Warning: Error processing customer 8 - name 'phone_col' is not defined
# Warning: Error processing customer 9 - name 'phone_col' is not defined
# Warning: Error processing customer 10 - name 'phone_col' is not defined
# Warning: Error processing customer 11 - name 'phone_col' is not defined
# Warning: Error processing customer 12 - name 'phone_col' is not defined
# Warning: Error processing customer 13 - name 'phone_col' is not defined
# Warning: Error processing customer 14 - name 'phone_col' is not defined
# Warning: Error processing customer 15 - name 'phone_col' is not defined
# Warning: Error processing customer 16 - name 'phone_col' is not defined
# Warning: Error processing customer 17 - name 'phone_col' is not defined
# Warning: Error processing customer 18 - name 'phone_col' is not defined
# Warning: Error processing customer 19 - name 'phone_col' is not defined
# Warning: Error processing customer 20 - name 'phone_col' is not defined
# Warning: Error processing customer 21 - name 'phone_col' is not defined
# Warning: Error processing customer 22 - name 'phone_col' is not defined
# Warning: Error processing customer 23 - name 'phone_col' is not defined
# Warning: Error processing customer 24 - name 'phone_col' is not defined
# Warning: Error processing customer 25 - name 'phone_col' is not defined
# Warning: Error processing customer 26 - name 'phone_col' is not defined
# Warning: Error processing customer 27 - name 'phone_col' is not defined
# Warning: Error processing customer 28 - name 'phone_col' is not defined
# Warning: Error processing customer 29 - name 'phone_col' is not defined
# Warning: Error processing customer 30 - name 'phone_col' is not defined
# Warning: Error processing customer 31 - name 'phone_col' is not defined
# Warning: Error processing customer 32 - name 'phone_col' is not defined
# Warning: Error processing customer 33 - name 'phone_col' is not defined
# Warning: Error processing customer 34 - name 'phone_col' is not defined
# Warning: Error processing customer 35 - name 'phone_col' is not defined
# Warning: Error processing customer 36 - name 'phone_col' is not defined
# Warning: Error processing customer 37 - name 'phone_col' is not defined
# Warning: Error processing customer 38 - name 'phone_col' is not defined
# Warning: Error processing customer 39 - name 'phone_col' is not defined
# Warning: Error processing customer 40 - name 'phone_col' is not defined
# Warning: Error processing customer 41 - name 'phone_col' is not defined
# Warning: Error processing customer 42 - name 'phone_col' is not defined
# Warning: Error processing customer 43 - name 'phone_col' is not defined
# Warning: Error processing customer 44 - name 'phone_col' is not defined
# Warning: Error processing customer 45 - name 'phone_col' is not defined
# Warning: Error processing customer 46 - name 'phone_col' is not defined
# Warning: Error processing customer 47 - name 'phone_col' is not defined
# Warning: Error processing customer 48 - name 'phone_col' is not defined
# Warning: Error processing customer 49 - name 'phone_col' is not defined
# Warning: Error processing customer 50 - name 'phone_col' is not defined
# Warning: Error processing customer 51 - name 'phone_col' is not defined
# Warning: Error processing customer 52 - name 'phone_col' is not defined
# Warning: Error processing customer 53 - name 'phone_col' is not defined
# Warning: Error processing customer 54 - name 'phone_col' is not defined
# Warning: Error processing customer 55 - name 'phone_col' is not defined
# Warning: Error processing customer 56 - name 'phone_col' is not defined
# Warning: Error processing customer 57 - name 'phone_col' is not defined
# Warning: Error processing customer 58 - name 'phone_col' is not defined
# Warning: Error processing customer 59 - name 'phone_col' is not defined
# Warning: Error processing customer 60 - name 'phone_col' is not defined
# Warning: Error processing customer 61 - name 'phone_col' is not defined
# Warning: Error processing customer 62 - name 'phone_col' is not defined
# Warning: Error processing customer 63 - name 'phone_col' is not defined
# Warning: Error processing customer 64 - name 'phone_col' is not defined
# Warning: Error processing customer 65 - name 'phone_col' is not defined
# Warning: Error processing customer 66 - name 'phone_col' is not defined
# Warning: Error processing customer 67 - name 'phone_col' is not defined
# Warning: Error processing customer 68 - name 'phone_col' is not defined
# Warning: Error processing customer 69 - name 'phone_col' is not defined
# Warning: Error processing customer 70 - name 'phone_col' is not defined
# Warning: Error processing customer 71 - name 'phone_col' is not defined
# Warning: Error processing customer 72 - name 'phone_col' is not defined
# Warning: Error processing customer 73 - name 'phone_col' is not defined
# Warning: Error processing customer 74 - name 'phone_col' is not defined
# Warning: Error processing customer 75 - name 'phone_col' is not defined
# Warning: Error processing customer 76 - name 'phone_col' is not defined
# Warning: Error processing customer 77 - name 'phone_col' is not defined
# Warning: Error processing customer 78 - name 'phone_col' is not defined
# Warning: Error processing customer 79 - name 'phone_col' is not defined
# Warning: Error processing customer 80 - name 'phone_col' is not defined
# Warning: Error processing customer 81 - name 'phone_col' is not defined
# Warning: Error processing customer 82 - name 'phone_col' is not defined
# Warning: Error processing customer 83 - name 'phone_col' is not defined
# Warning: Error processing customer 84 - name 'phone_col' is not defined
# Warning: Error processing customer 85 - name 'phone_col' is not defined
# Warning: Error processing customer 86 - name 'phone_col' is not defined
# Warning: Error processing customer 87 - name 'phone_col' is not defined
# Warning: Error processing customer 88 - name 'phone_col' is not defined
# Warning: Error processing customer 89 - name 'phone_col' is not defined
# Warning: Error processing customer 90 - name 'phone_col' is not defined
# Warning: Error processing customer 91 - name 'phone_col' is not defined
# Warning: Error processing customer 92 - name 'phone_col' is not defined
# Warning: Error processing customer 93 - name 'phone_col' is not defined
# Warning: Error processing customer 94 - name 'phone_col' is not defined
# Warning: Error processing customer 95 - name 'phone_col' is not defined
# Warning: Error processing customer 96 - name 'phone_col' is not defined
# Warning: Error processing customer 97 - name 'phone_col' is not defined
# Warning: Error processing customer 98 - name 'phone_col' is not defined
# Warning: Error processing customer 99 - name 'phone_col' is not defined
# Warning: Error processing customer 100 - name 'phone_col' is not defined
# Warning: Error processing customer 101 - name 'phone_col' is not defined
# Warning: Error processing customer 102 - name 'phone_col' is not defined
# Warning: Error processing customer 103 - name 'phone_col' is not defined
# Warning: Error processing customer 104 - name 'phone_col' is not defined
# Warning: Error processing customer 105 - name 'phone_col' is not defined
# Warning: Error processing customer 106 - name 'phone_col' is not defined
# Warning: Error processing customer 107 - name 'phone_col' is not defined
# Warning: Error processing customer 108 - name 'phone_col' is not defined
# Warning: Error processing customer 109 - name 'phone_col' is not defined
# Warning: Error processing customer 110 - name 'phone_col' is not defined
# Warning: Error processing customer 111 - name 'phone_col' is not defined
# Warning: Error processing customer 112 - name 'phone_col' is not defined
# Warning: Error processing customer 113 - name 'phone_col' is not defined
# Warning: Error processing customer 114 - name 'phone_col' is not defined
# Warning: Error processing customer 115 - name 'phone_col' is not defined
# Warning: Error processing customer 116 - name 'phone_col' is not defined
# Warning: Error processing customer 117 - name 'phone_col' is not defined
# Warning: Error processing customer 118 - name 'phone_col' is not defined
# Warning: Error processing customer 119 - name 'phone_col' is not defined
# Warning: Error processing customer 120 - name 'phone_col' is not defined
# Warning: Error processing customer 121 - name 'phone_col' is not defined
# Warning: Error processing customer 122 - name 'phone_col' is not defined
# Warning: Error processing customer 123 - name 'phone_col' is not defined
# Warning: Error processing customer 124 - name 'phone_col' is not defined
# Warning: Error processing customer 125 - name 'phone_col' is not defined
# Warning: Error processing customer 126 - name 'phone_col' is not defined
# Warning: Error processing customer 127 - name 'phone_col' is not defined
# Warning: Error processing customer 128 - name 'phone_col' is not defined
# Warning: Error processing customer 129 - name 'phone_col' is not defined
# Warning: Error processing customer 130 - name 'phone_col' is not defined
# Warning: Error processing customer 131 - name 'phone_col' is not defined
# Warning: Error processing customer 132 - name 'phone_col' is not defined
# Warning: Error processing customer 133 - name 'phone_col' is not defined
# Warning: Error processing customer 134 - name 'phone_col' is not defined
# Warning: Error processing customer 135 - name 'phone_col' is not defined
# Warning: Error processing customer 136 - name 'phone_col' is not defined
# Warning: Error processing customer 137 - name 'phone_col' is not defined
# Warning: Error processing customer 138 - name 'phone_col' is not defined
# Warning: Error processing customer 139 - name 'phone_col' is not defined
# Warning: Error processing customer 140 - name 'phone_col' is not defined
# Warning: Error processing customer 141 - name 'phone_col' is not defined
# Warning: Error processing customer 142 - name 'phone_col' is not defined
# Warning: Error processing customer 143 - name 'phone_col' is not defined
# Warning: Error processing customer 144 - name 'phone_col' is not defined
# Warning: Error processing customer 145 - name 'phone_col' is not defined
# Warning: Error processing customer 146 - name 'phone_col' is not defined
# Warning: Error processing customer 147 - name 'phone_col' is not defined
# Warning: Error processing customer 148 - name 'phone_col' is not defined
# Warning: Error processing customer 149 - name 'phone_col' is not defined
# Warning: Error processing customer 150 - name 'phone_col' is not defined
# Warning: Error processing customer 151 - name 'phone_col' is not defined
# Warning: Error processing customer 152 - name 'phone_col' is not defined
# Warning: Error processing customer 153 - name 'phone_col' is not defined
# Warning: Error processing customer 154 - name 'phone_col' is not defined
# Warning: Error processing customer 155 - name 'phone_col' is not defined
# Warning: Error processing customer 156 - name 'phone_col' is not defined
# Warning: Error processing customer 157 - name 'phone_col' is not defined
# Warning: Error processing customer 158 - name 'phone_col' is not defined
# Warning: Error processing customer 159 - name 'phone_col' is not defined
# Warning: Error processing customer 160 - name 'phone_col' is not defined
# Warning: Error processing customer 161 - name 'phone_col' is not defined
# Warning: Error processing customer 162 - name 'phone_col' is not defined
# Warning: Error processing customer 163 - name 'phone_col' is not defined
# Warning: Error processing customer 164 - name 'phone_col' is not defined
# Warning: Error processing customer 165 - name 'phone_col' is not defined
# Warning: Error processing customer 166 - name 'phone_col' is not defined
# Warning: Error processing customer 167 - name 'phone_col' is not defined
# Warning: Error processing customer 168 - name 'phone_col' is not defined
# Warning: Error processing customer 169 - name 'phone_col' is not defined
# Warning: Error processing customer 170 - name 'phone_col' is not defined
# Warning: Error processing customer 171 - name 'phone_col' is not defined
# Warning: Error processing customer 172 - name 'phone_col' is not defined
# Warning: Error processing customer 173 - name 'phone_col' is not defined
# Warning: Error processing customer 174 - name 'phone_col' is not defined
# Warning: Error processing customer 175 - name 'phone_col' is not defined
# Warning: Error processing customer 176 - name 'phone_col' is not defined
# Warning: Error processing customer 177 - name 'phone_col' is not defined
# Warning: Error processing customer 178 - name 'phone_col' is not defined
# Warning: Error processing customer 179 - name 'phone_col' is not defined
# Warning: Error processing customer 180 - name 'phone_col' is not defined
# Warning: Error processing customer 181 - name 'phone_col' is not defined
# Warning: Error processing customer 182 - name 'phone_col' is not defined
# Warning: Error processing customer 183 - name 'phone_col' is not defined
# Warning: Error processing customer 184 - name 'phone_col' is not defined
# Warning: Error processing customer 185 - name 'phone_col' is not defined
# Warning: Error processing customer 186 - name 'phone_col' is not defined
# Warning: Error processing customer 187 - name 'phone_col' is not defined
# Warning: Error processing customer 188 - name 'phone_col' is not defined
# Warning: Error processing customer 189 - name 'phone_col' is not defined
# Warning: Error processing customer 190 - name 'phone_col' is not defined
# Warning: Error processing customer 191 - name 'phone_col' is not defined
# Warning: Error processing customer 192 - name 'phone_col' is not defined
# Warning: Error processing customer 193 - name 'phone_col' is not defined
# Warning: Error processing customer 194 - name 'phone_col' is not defined
# Warning: Error processing customer 195 - name 'phone_col' is not defined
# Warning: Error processing customer 196 - name 'phone_col' is not defined
# Warning: Error processing customer 197 - name 'phone_col' is not defined
# Warning: Error processing customer 198 - name 'phone_col' is not defined
# Warning: Error processing customer 199 - name 'phone_col' is not defined
# Warning: Error processing customer 200 - name 'phone_col' is not defined
# Warning: Error processing customer 201 - name 'phone_col' is not defined
# Warning: Error processing customer 202 - name 'phone_col' is not defined
# Warning: Error processing customer 203 - name 'phone_col' is not defined
# Warning: Error processing customer 204 - name 'phone_col' is not defined
# Warning: Error processing customer 205 - name 'phone_col' is not defined
# Warning: Error processing customer 206 - name 'phone_col' is not defined
# Warning: Error processing customer 207 - name 'phone_col' is not defined
# Warning: Error processing customer 208 - name 'phone_col' is not defined
# Warning: Error processing customer 209 - name 'phone_col' is not defined
# Warning: Error processing customer 210 - name 'phone_col' is not defined
# Warning: Error processing customer 211 - name 'phone_col' is not defined
# Warning: Error processing customer 212 - name 'phone_col' is not defined
# Warning: Error processing customer 213 - name 'phone_col' is not defined
# Warning: Error processing customer 214 - name 'phone_col' is not defined
# Warning: Error processing customer 215 - name 'phone_col' is not defined
# Warning: Error processing customer 216 - name 'phone_col' is not defined
# Warning: Error processing customer 217 - name 'phone_col' is not defined
# Warning: Error processing customer 218 - name 'phone_col' is not defined
# Warning: Error processing customer 219 - name 'phone_col' is not defined
# Warning: Error processing customer 220 - name 'phone_col' is not defined
# Warning: Error processing customer 221 - name 'phone_col' is not defined
# Warning: Error processing customer 222 - name 'phone_col' is not defined
# Warning: Error processing customer 223 - name 'phone_col' is not defined
# Warning: Error processing customer 224 - name 'phone_col' is not defined
# Warning: Error processing customer 225 - name 'phone_col' is not defined
# Warning: Error processing customer 226 - name 'phone_col' is not defined
# Warning: Error processing customer 227 - name 'phone_col' is not defined
# Warning: Error processing customer 228 - name 'phone_col' is not defined
# Warning: Error processing customer 229 - name 'phone_col' is not defined
# Warning: Error processing customer 230 - name 'phone_col' is not defined
# Warning: Error processing customer 231 - name 'phone_col' is not defined
# Warning: Error processing customer 232 - name 'phone_col' is not defined
# Warning: Error processing customer 233 - name 'phone_col' is not defined
# Warning: Error processing customer 234 - name 'phone_col' is not defined
# Warning: Error processing customer 235 - name 'phone_col' is not defined
# Warning: Error processing customer 236 - name 'phone_col' is not defined
# Warning: Error processing customer 237 - name 'phone_col' is not defined
# Warning: Error processing customer 238 - name 'phone_col' is not defined
# Warning: Error processing customer 239 - name 'phone_col' is not defined
# Warning: Error processing customer 240 - name 'phone_col' is not defined
# Warning: Error processing customer 241 - name 'phone_col' is not defined
# Warning: Error processing customer 242 - name 'phone_col' is not defined
# Warning: Error processing customer 243 - name 'phone_col' is not defined
# Warning: Error processing customer 244 - name 'phone_col' is not defined
# Warning: Error processing customer 245 - name 'phone_col' is not defined
# Warning: Error processing customer 246 - name 'phone_col' is not defined
# Warning: Error processing customer 247 - name 'phone_col' is not defined
# Warning: Error processing customer 248 - name 'phone_col' is not defined
# Warning: Error processing customer 249 - name 'phone_col' is not defined
# Warning: Error processing customer 250 - name 'phone_col' is not defined
# Warning: Error processing customer 251 - name 'phone_col' is not defined
# Warning: Error processing customer 252 - name 'phone_col' is not defined
# Warning: Error processing customer 253 - name 'phone_col' is not defined
# Warning: Error processing customer 254 - name 'phone_col' is not defined
# Warning: Error processing customer 255 - name 'phone_col' is not defined
# Warning: Error processing customer 256 - name 'phone_col' is not defined
# Warning: Error processing customer 257 - name 'phone_col' is not defined
# Warning: Error processing customer 258 - name 'phone_col' is not defined
# Warning: Error processing customer 259 - name 'phone_col' is not defined
# Warning: Error processing customer 260 - name 'phone_col' is not defined
# Warning: Error processing customer 261 - name 'phone_col' is not defined
# Warning: Error processing customer 262 - name 'phone_col' is not defined
# Warning: Error processing customer 263 - name 'phone_col' is not defined
# Warning: Error processing customer 264 - name 'phone_col' is not defined
# Warning: Error processing customer 265 - name 'phone_col' is not defined
# Warning: Error processing customer 266 - name 'phone_col' is not defined
# Warning: Error processing customer 267 - name 'phone_col' is not defined
# Warning: Error processing customer 268 - name 'phone_col' is not defined
# Warning: Error processing customer 269 - name 'phone_col' is not defined
# Warning: Error processing customer 270 - name 'phone_col' is not defined
# Warning: Error processing customer 271 - name 'phone_col' is not defined
# Warning: Error processing customer 272 - name 'phone_col' is not defined
# Warning: Error processing customer 273 - name 'phone_col' is not defined
# Warning: Error processing customer 274 - name 'phone_col' is not defined
# Warning: Error processing customer 275 - name 'phone_col' is not defined
# Warning: Error processing customer 276 - name 'phone_col' is not defined
# Warning: Error processing customer 277 - name 'phone_col' is not defined
# Warning: Error processing customer 278 - name 'phone_col' is not defined
# Warning: Error processing customer 279 - name 'phone_col' is not defined
# Warning: Error processing customer 280 - name 'phone_col' is not defined
# Warning: Error processing customer 281 - name 'phone_col' is not defined
# Warning: Error processing customer 282 - name 'phone_col' is not defined
# Warning: Error processing customer 283 - name 'phone_col' is not defined
# Warning: Error processing customer 284 - name 'phone_col' is not defined
# Warning: Error processing customer 285 - name 'phone_col' is not defined
# Warning: Error processing customer 286 - name 'phone_col' is not defined
# Warning: Error processing customer 287 - name 'phone_col' is not defined
# Warning: Error processing customer 288 - name 'phone_col' is not defined
# Warning: Error processing customer 289 - name 'phone_col' is not defined
# Warning: Error processing customer 290 - name 'phone_col' is not defined
# Warning: Error processing customer 291 - name 'phone_col' is not defined
# Warning: Error processing customer 292 - name 'phone_col' is not defined
# Warning: Error processing customer 293 - name 'phone_col' is not defined
# Warning: Error processing customer 294 - name 'phone_col' is not defined
# Warning: Error processing customer 295 - name 'phone_col' is not defined
# Warning: Error processing customer 296 - name 'phone_col' is not defined
# Warning: Error processing customer 297 - name 'phone_col' is not defined
# Warning: Error processing customer 298 - name 'phone_col' is not defined
# Warning: Error processing customer 299 - name 'phone_col' is not defined
# Warning: Error processing customer 300 - name 'phone_col' is not defined
# Warning: Error processing customer 301 - name 'phone_col' is not defined
# Warning: Error processing customer 302 - name 'phone_col' is not defined
# Warning: Error processing customer 303 - name 'phone_col' is not defined
# Warning: Error processing customer 304 - name 'phone_col' is not defined
# Warning: Error processing customer 305 - name 'phone_col' is not defined
# Warning: Error processing customer 306 - name 'phone_col' is not defined
# Warning: Error processing customer 307 - name 'phone_col' is not defined
# Warning: Error processing customer 308 - name 'phone_col' is not defined
# Warning: Error processing customer 309 - name 'phone_col' is not defined
# Warning: Error processing customer 310 - name 'phone_col' is not defined
# Warning: Error processing customer 311 - name 'phone_col' is not defined
# Warning: Error processing customer 312 - name 'phone_col' is not defined
# Warning: Error processing customer 313 - name 'phone_col' is not defined
# Warning: Error processing customer 314 - name 'phone_col' is not defined
# Warning: Error processing customer 315 - name 'phone_col' is not defined
# Warning: Error processing customer 316 - name 'phone_col' is not defined
# Warning: Error processing customer 317 - name 'phone_col' is not defined
# Warning: Error processing customer 318 - name 'phone_col' is not defined
# Warning: Error processing customer 319 - name 'phone_col' is not defined
# Warning: Error processing customer 320 - name 'phone_col' is not defined
# Warning: Error processing customer 321 - name 'phone_col' is not defined
# Warning: Error processing customer 322 - name 'phone_col' is not defined
# Warning: Error processing customer 323 - name 'phone_col' is not defined
# Warning: Error processing customer 324 - name 'phone_col' is not defined
# Warning: Error processing customer 325 - name 'phone_col' is not defined
# Warning: Error processing customer 326 - name 'phone_col' is not defined
# Warning: Error processing customer 327 - name 'phone_col' is not defined
# Warning: Error processing customer 328 - name 'phone_col' is not defined
# Warning: Error processing customer 329 - name 'phone_col' is not defined
# Warning: Error processing customer 330 - name 'phone_col' is not defined
# Warning: Error processing customer 331 - name 'phone_col' is not defined
# Warning: Error processing customer 332 - name 'phone_col' is not defined
# Warning: Error processing customer 333 - name 'phone_col' is not defined
# Warning: Error processing customer 334 - name 'phone_col' is not defined
# Warning: Error processing customer 335 - name 'phone_col' is not defined
# Warning: Error processing customer 336 - name 'phone_col' is not defined
# Warning: Error processing customer 337 - name 'phone_col' is not defined
# Warning: Error processing customer 338 - name 'phone_col' is not defined
# Warning: Error processing customer 339 - name 'phone_col' is not defined
# Warning: Error processing customer 340 - name 'phone_col' is not defined
# Warning: Error processing customer 341 - name 'phone_col' is not defined
# Warning: Error processing customer 342 - name 'phone_col' is not defined
# Warning: Error processing customer 343 - name 'phone_col' is not defined
# Warning: Error processing customer 344 - name 'phone_col' is not defined
# Warning: Error processing customer 345 - name 'phone_col' is not defined
# Warning: Error processing customer 346 - name 'phone_col' is not defined
# Warning: Error processing customer 347 - name 'phone_col' is not defined
# Warning: Error processing customer 348 - name 'phone_col' is not defined
# Warning: Error processing customer 349 - name 'phone_col' is not defined
# Warning: Error processing customer 350 - name 'phone_col' is not defined
# Warning: Error processing customer 351 - name 'phone_col' is not defined
# Warning: Error processing customer 352 - name 'phone_col' is not defined
# Warning: Error processing customer 353 - name 'phone_col' is not defined
# Warning: Error processing customer 354 - name 'phone_col' is not defined
# Warning: Error processing customer 355 - name 'phone_col' is not defined
# Warning: Error processing customer 356 - name 'phone_col' is not defined
# Warning: Error processing customer 357 - name 'phone_col' is not defined
# Warning: Error processing customer 358 - name 'phone_col' is not defined
# Warning: Error processing customer 359 - name 'phone_col' is not defined
# Warning: Error processing customer 360 - name 'phone_col' is not defined
# Warning: Error processing customer 361 - name 'phone_col' is not defined
# Warning: Error processing customer 362 - name 'phone_col' is not defined
# Warning: Error processing customer 363 - name 'phone_col' is not defined
# Warning: Error processing customer 364 - name 'phone_col' is not defined
# Warning: Error processing customer 365 - name 'phone_col' is not defined
# Warning: Error processing customer 366 - name 'phone_col' is not defined
# Warning: Error processing customer 367 - name 'phone_col' is not defined
# Warning: Error processing customer 368 - name 'phone_col' is not defined
# Warning: Error processing customer 369 - name 'phone_col' is not defined
# Warning: Error processing customer 370 - name 'phone_col' is not defined
# Warning: Error processing customer 371 - name 'phone_col' is not defined
# Warning: Error processing customer 372 - name 'phone_col' is not defined
# Warning: Error processing customer 373 - name 'phone_col' is not defined
# Warning: Error processing customer 374 - name 'phone_col' is not defined
# Warning: Error processing customer 375 - name 'phone_col' is not defined
# Warning: Error processing customer 376 - name 'phone_col' is not defined
# Warning: Error processing customer 377 - name 'phone_col' is not defined
# Warning: Error processing customer 378 - name 'phone_col' is not defined
# Warning: Error processing customer 379 - name 'phone_col' is not defined
# Warning: Error processing customer 380 - name 'phone_col' is not defined
# Warning: Error processing customer 381 - name 'phone_col' is not defined
# Warning: Error processing customer 382 - name 'phone_col' is not defined
# Warning: Error processing customer 383 - name 'phone_col' is not defined
# Warning: Error processing customer 384 - name 'phone_col' is not defined
# Warning: Error processing customer 385 - name 'phone_col' is not defined
# Warning: Error processing customer 386 - name 'phone_col' is not defined
# Warning: Error processing customer 387 - name 'phone_col' is not defined
# Warning: Error processing customer 388 - name 'phone_col' is not defined
# Warning: Error processing customer 389 - name 'phone_col' is not defined
# Warning: Error processing customer 390 - name 'phone_col' is not defined
# Warning: Error processing customer 391 - name 'phone_col' is not defined
# Warning: Error processing customer 392 - name 'phone_col' is not defined
# Warning: Error processing customer 393 - name 'phone_col' is not defined
# Warning: Error processing customer 394 - name 'phone_col' is not defined
# Warning: Error processing customer 395 - name 'phone_col' is not defined
# Warning: Error processing customer 396 - name 'phone_col' is not defined
# Warning: Error processing customer 397 - name 'phone_col' is not defined
# Warning: Error processing customer 398 - name 'phone_col' is not defined
# Warning: Error processing customer 399 - name 'phone_col' is not defined
# Warning: Error processing customer 400 - name 'phone_col' is not defined
# Warning: Error processing customer 401 - name 'phone_col' is not defined
# Warning: Error processing customer 402 - name 'phone_col' is not defined
# Warning: Error processing customer 403 - name 'phone_col' is not defined
# Warning: Error processing customer 404 - name 'phone_col' is not defined
# Warning: Error processing customer 405 - name 'phone_col' is not defined
# Warning: Error processing customer 406 - name 'phone_col' is not defined
# Warning: Error processing customer 407 - name 'phone_col' is not defined
# Warning: Error processing customer 408 - name 'phone_col' is not defined
# Warning: Error processing customer 409 - name 'phone_col' is not defined
# Warning: Error processing customer 410 - name 'phone_col' is not defined
# Warning: Error processing customer 411 - name 'phone_col' is not defined
# Warning: Error processing customer 412 - name 'phone_col' is not defined
# Warning: Error processing customer 413 - name 'phone_col' is not defined
# Warning: Error processing customer 414 - name 'phone_col' is not defined
# Warning: Error processing customer 415 - name 'phone_col' is not defined
# Warning: Error processing customer 416 - name 'phone_col' is not defined
# Warning: Error processing customer 417 - name 'phone_col' is not defined
# Warning: Error processing customer 418 - name 'phone_col' is not defined
# Warning: Error processing customer 419 - name 'phone_col' is not defined
# Warning: Error processing customer 420 - name 'phone_col' is not defined
# Warning: Error processing customer 421 - name 'phone_col' is not defined
# Warning: Error processing customer 422 - name 'phone_col' is not defined
# Warning: Error processing customer 423 - name 'phone_col' is not defined
# Warning: Error processing customer 424 - name 'phone_col' is not defined
# Warning: Error processing customer 425 - name 'phone_col' is not defined
# Warning: Error processing customer 426 - name 'phone_col' is not defined
# Warning: Error processing customer 427 - name 'phone_col' is not defined
# Warning: Error processing customer 428 - name 'phone_col' is not defined
# Warning: Error processing customer 429 - name 'phone_col' is not defined
# Warning: Error processing customer 430 - name 'phone_col' is not defined
# Warning: Error processing customer 431 - name 'phone_col' is not defined
# Warning: Error processing customer 432 - name 'phone_col' is not defined
# Warning: Error processing customer 433 - name 'phone_col' is not defined
# Warning: Error processing customer 434 - name 'phone_col' is not defined
# Warning: Error processing customer 435 - name 'phone_col' is not defined
# Warning: Error processing customer 436 - name 'phone_col' is not defined
# Warning: Error processing customer 437 - name 'phone_col' is not defined
# Warning: Error processing customer 438 - name 'phone_col' is not defined
# Warning: Error processing customer 439 - name 'phone_col' is not defined
# Warning: Error processing customer 440 - name 'phone_col' is not defined
# Warning: Error processing customer 441 - name 'phone_col' is not defined
# Warning: Error processing customer 442 - name 'phone_col' is not defined
# Warning: Error processing customer 443 - name 'phone_col' is not defined
# Warning: Error processing customer 444 - name 'phone_col' is not defined
# Warning: Error processing customer 445 - name 'phone_col' is not defined
# Warning: Error processing customer 446 - name 'phone_col' is not defined
# Warning: Error processing customer 447 - name 'phone_col' is not defined
# Warning: Error processing customer 448 - name 'phone_col' is not defined
# Warning: Error processing customer 449 - name 'phone_col' is not defined
# Warning: Error processing customer 450 - name 'phone_col' is not defined
# Warning: Error processing customer 451 - name 'phone_col' is not defined
# Warning: Error processing customer 452 - name 'phone_col' is not defined
# Warning: Error processing customer 453 - name 'phone_col' is not defined
# Warning: Error processing customer 454 - name 'phone_col' is not defined
# Warning: Error processing customer 455 - name 'phone_col' is not defined
# Warning: Error processing customer 456 - name 'phone_col' is not defined
# Warning: Error processing customer 457 - name 'phone_col' is not defined
# Warning: Error processing customer 458 - name 'phone_col' is not defined
# Warning: Error processing customer 459 - name 'phone_col' is not defined
# Warning: Error processing customer 460 - name 'phone_col' is not defined
# Warning: Error processing customer 461 - name 'phone_col' is not defined
# Warning: Error processing customer 462 - name 'phone_col' is not defined
# Warning: Error processing customer 463 - name 'phone_col' is not defined
# Warning: Error processing customer 464 - name 'phone_col' is not defined
# Warning: Error processing customer 465 - name 'phone_col' is not defined
# Warning: Error processing customer 466 - name 'phone_col' is not defined
# Warning: Error processing customer 467 - name 'phone_col' is not defined
# Warning: Error processing customer 468 - name 'phone_col' is not defined
# Warning: Error processing customer 469 - name 'phone_col' is not defined
# Warning: Error processing customer 470 - name 'phone_col' is not defined
# Warning: Error processing customer 471 - name 'phone_col' is not defined
# Warning: Error processing customer 472 - name 'phone_col' is not defined
# Warning: Error processing customer 473 - name 'phone_col' is not defined
# Warning: Error processing customer 474 - name 'phone_col' is not defined
# Warning: Error processing customer 475 - name 'phone_col' is not defined
# Warning: Error processing customer 476 - name 'phone_col' is not defined
# Warning: Error processing customer 477 - name 'phone_col' is not defined
# Warning: Error processing customer 478 - name 'phone_col' is not defined
# Warning: Error processing customer 479 - name 'phone_col' is not defined
# Warning: Error processing customer 480 - name 'phone_col' is not defined
# Warning: Error processing customer 481 - name 'phone_col' is not defined
# Warning: Error processing customer 482 - name 'phone_col' is not defined
# Warning: Error processing customer 483 - name 'phone_col' is not defined
# Warning: Error processing customer 484 - name 'phone_col' is not defined
# Warning: Error processing customer 485 - name 'phone_col' is not defined
# Warning: Error processing customer 486 - name 'phone_col' is not defined
# Warning: Error processing customer 487 - name 'phone_col' is not defined
# Warning: Error processing customer 488 - name 'phone_col' is not defined
# Warning: Error processing customer 489 - name 'phone_col' is not defined
# Warning: Error processing customer 490 - name 'phone_col' is not defined
# Warning: Error processing customer 491 - name 'phone_col' is not defined
# Warning: Error processing customer 492 - name 'phone_col' is not defined
# Warning: Error processing customer 493 - name 'phone_col' is not defined
# Warning: Error processing customer 494 - name 'phone_col' is not defined
# Warning: Error processing customer 495 - name 'phone_col' is not defined
# Warning: Error processing customer 496 - name 'phone_col' is not defined
# Warning: Error processing customer 497 - name 'phone_col' is not defined
# Warning: Error processing customer 498 - name 'phone_col' is not defined
# Warning: Error processing customer 499 - name 'phone_col' is not defined
# Warning: Error processing customer 500 - name 'phone_col' is not defined
# Warning: Error processing customer 501 - name 'phone_col' is not defined
# Warning: Error processing customer 502 - name 'phone_col' is not defined
# Warning: Error processing customer 503 - name 'phone_col' is not defined
# Warning: Error processing customer 504 - name 'phone_col' is not defined
# Warning: Error processing customer 505 - name 'phone_col' is not defined
# Warning: Error processing customer 506 - name 'phone_col' is not defined
# Warning: Error processing customer 507 - name 'phone_col' is not defined
# Warning: Error processing customer 508 - name 'phone_col' is not defined
# Warning: Error processing customer 509 - name 'phone_col' is not defined
# Warning: Error processing customer 510 - name 'phone_col' is not defined
# Warning: Error processing customer 511 - name 'phone_col' is not defined
# Warning: Error processing customer 512 - name 'phone_col' is not defined
# Warning: Error processing customer 513 - name 'phone_col' is not defined
# Warning: Error processing customer 514 - name 'phone_col' is not defined
# Warning: Error processing customer 515 - name 'phone_col' is not defined
# Warning: Error processing customer 516 - name 'phone_col' is not defined
# Warning: Error processing customer 517 - name 'phone_col' is not defined
# Warning: Error processing customer 518 - name 'phone_col' is not defined
# Warning: Error processing customer 519 - name 'phone_col' is not defined
# Warning: Error processing customer 520 - name 'phone_col' is not defined
# Warning: Error processing customer 521 - name 'phone_col' is not defined
# Warning: Error processing customer 522 - name 'phone_col' is not defined
# Warning: Error processing customer 523 - name 'phone_col' is not defined
# Warning: Error processing customer 524 - name 'phone_col' is not defined
# Warning: Error processing customer 525 - name 'phone_col' is not defined
# Warning: Error processing customer 526 - name 'phone_col' is not defined
# Warning: Error processing customer 527 - name 'phone_col' is not defined
# Warning: Error processing customer 528 - name 'phone_col' is not defined
# Warning: Error processing customer 529 - name 'phone_col' is not defined
# Warning: Error processing customer 530 - name 'phone_col' is not defined
# Warning: Error processing customer 531 - name 'phone_col' is not defined
# Warning: Error processing customer 532 - name 'phone_col' is not defined
# Warning: Error processing customer 533 - name 'phone_col' is not defined
# Warning: Error processing customer 534 - name 'phone_col' is not defined
# Warning: Error processing customer 535 - name 'phone_col' is not defined
# Warning: Error processing customer 536 - name 'phone_col' is not defined
# Warning: Error processing customer 537 - name 'phone_col' is not defined
# Warning: Error processing customer 538 - name 'phone_col' is not defined
# Warning: Error processing customer 539 - name 'phone_col' is not defined
# Warning: Error processing customer 540 - name 'phone_col' is not defined
# Warning: Error processing customer 541 - name 'phone_col' is not defined
# Warning: Error processing customer 542 - name 'phone_col' is not defined
# Warning: Error processing customer 543 - name 'phone_col' is not defined
# Warning: Error processing customer 544 - name 'phone_col' is not defined
# Warning: Error processing customer 545 - name 'phone_col' is not defined
# Warning: Error processing customer 546 - name 'phone_col' is not defined
# Warning: Error processing customer 547 - name 'phone_col' is not defined
# Warning: Error processing customer 548 - name 'phone_col' is not defined
# Warning: Error processing customer 549 - name 'phone_col' is not defined
# Warning: Error processing customer 550 - name 'phone_col' is not defined
# Warning: Error processing customer 551 - name 'phone_col' is not defined
# Warning: Error processing customer 552 - name 'phone_col' is not defined
# Warning: Error processing customer 553 - name 'phone_col' is not defined
# Warning: Error processing customer 554 - name 'phone_col' is not defined
# Warning: Error processing customer 555 - name 'phone_col' is not defined
# Warning: Error processing customer 556 - name 'phone_col' is not defined
# Warning: Error processing customer 557 - name 'phone_col' is not defined
# Warning: Error processing customer 558 - name 'phone_col' is not defined
# Warning: Error processing customer 559 - name 'phone_col' is not defined
# Warning: Error processing customer 560 - name 'phone_col' is not defined
# Warning: Error processing customer 561 - name 'phone_col' is not defined
# Warning: Error processing customer 562 - name 'phone_col' is not defined
# Warning: Error processing customer 563 - name 'phone_col' is not defined
# Warning: Error processing customer 564 - name 'phone_col' is not defined
# Warning: Error processing customer 565 - name 'phone_col' is not defined
# Warning: Error processing customer 566 - name 'phone_col' is not defined
# Warning: Error processing customer 567 - name 'phone_col' is not defined
# Warning: Error processing customer 568 - name 'phone_col' is not defined
# Warning: Error processing customer 569 - name 'phone_col' is not defined
# Warning: Error processing customer 570 - name 'phone_col' is not defined
# Warning: Error processing customer 571 - name 'phone_col' is not defined
# Warning: Error processing customer 572 - name 'phone_col' is not defined
# Warning: Error processing customer 573 - name 'phone_col' is not defined
# Warning: Error processing customer 574 - name 'phone_col' is not defined
# Warning: Error processing customer 575 - name 'phone_col' is not defined
# Warning: Error processing customer 576 - name 'phone_col' is not defined
# Warning: Error processing customer 577 - name 'phone_col' is not defined
# Warning: Error processing customer 578 - name 'phone_col' is not defined
# Warning: Error processing customer 579 - name 'phone_col' is not defined
# Warning: Error processing customer 580 - name 'phone_col' is not defined
# Warning: Error processing customer 581 - name 'phone_col' is not defined
# Warning: Error processing customer 582 - name 'phone_col' is not defined
# Warning: Error processing customer 583 - name 'phone_col' is not defined
# Warning: Error processing customer 584 - name 'phone_col' is not defined
# Warning: Error processing customer 585 - name 'phone_col' is not defined
# Warning: Error processing customer 586 - name 'phone_col' is not defined
# Warning: Error processing customer 587 - name 'phone_col' is not defined
# Warning: Error processing customer 588 - name 'phone_col' is not defined
# Warning: Error processing customer 589 - name 'phone_col' is not defined
# Warning: Error processing customer 590 - name 'phone_col' is not defined
# Warning: Error processing customer 591 - name 'phone_col' is not defined
# Warning: Error processing customer 592 - name 'phone_col' is not defined
# Warning: Error processing customer 593 - name 'phone_col' is not defined
# Warning: Error processing customer 594 - name 'phone_col' is not defined
# Warning: Error processing customer 595 - name 'phone_col' is not defined
# Warning: Error processing customer 596 - name 'phone_col' is not defined
# Warning: Error processing customer 597 - name 'phone_col' is not defined
# Warning: Error processing customer 598 - name 'phone_col' is not defined
# Warning: Error processing customer 599 - name 'phone_col' is not defined
# Warning: Error processing customer 600 - name 'phone_col' is not defined
# Warning: Error processing customer 601 - name 'phone_col' is not defined
# Warning: Error processing customer 602 - name 'phone_col' is not defined
# Warning: Error processing customer 603 - name 'phone_col' is not defined
# Warning: Error processing customer 604 - name 'phone_col' is not defined
# Warning: Error processing customer 605 - name 'phone_col' is not defined
# Warning: Error processing customer 606 - name 'phone_col' is not defined
# Warning: Error processing customer 607 - name 'phone_col' is not defined
# Warning: Error processing customer 608 - name 'phone_col' is not defined
# Warning: Error processing customer 609 - name 'phone_col' is not defined
# Warning: Error processing customer 610 - name 'phone_col' is not defined
# Warning: Error processing customer 611 - name 'phone_col' is not defined
# Warning: Error processing customer 612 - name 'phone_col' is not defined
# Warning: Error processing customer 613 - name 'phone_col' is not defined
# Warning: Error processing customer 614 - name 'phone_col' is not defined
# Warning: Error processing customer 615 - name 'phone_col' is not defined
# Warning: Error processing customer 616 - name 'phone_col' is not defined
# Warning: Error processing customer 617 - name 'phone_col' is not defined
# Warning: Error processing customer 618 - name 'phone_col' is not defined
# Warning: Error processing customer 619 - name 'phone_col' is not defined
# Warning: Error processing customer 620 - name 'phone_col' is not defined
# Warning: Error processing customer 621 - name 'phone_col' is not defined
# Warning: Error processing customer 622 - name 'phone_col' is not defined
# Warning: Error processing customer 623 - name 'phone_col' is not defined
# Warning: Error processing customer 624 - name 'phone_col' is not defined
# Warning: Error processing customer 625 - name 'phone_col' is not defined
# Warning: Error processing customer 626 - name 'phone_col' is not defined
# Warning: Error processing customer 627 - name 'phone_col' is not defined
# Warning: Error processing customer 628 - name 'phone_col' is not defined
# Warning: Error processing customer 629 - name 'phone_col' is not defined
# Warning: Error processing customer 630 - name 'phone_col' is not defined
# Warning: Error processing customer 631 - name 'phone_col' is not defined
# Warning: Error processing customer 632 - name 'phone_col' is not defined
# Warning: Error processing customer 633 - name 'phone_col' is not defined
# Warning: Error processing customer 634 - name 'phone_col' is not defined
# Warning: Error processing customer 635 - name 'phone_col' is not defined
# Warning: Error processing customer 636 - name 'phone_col' is not defined
# Warning: Error processing customer 637 - name 'phone_col' is not defined
# Warning: Error processing customer 638 - name 'phone_col' is not defined
# Warning: Error processing customer 639 - name 'phone_col' is not defined
# Warning: Error processing customer 640 - name 'phone_col' is not defined
# Warning: Error processing customer 641 - name 'phone_col' is not defined
# Warning: Error processing customer 642 - name 'phone_col' is not defined
# Warning: Error processing customer 643 - name 'phone_col' is not defined
# Warning: Error processing customer 644 - name 'phone_col' is not defined
# Warning: Error processing customer 645 - name 'phone_col' is not defined
# Warning: Error processing customer 646 - name 'phone_col' is not defined
# Warning: Error processing customer 647 - name 'phone_col' is not defined
# Warning: Error processing customer 648 - name 'phone_col' is not defined
# Warning: Error processing customer 649 - name 'phone_col' is not defined
# Warning: Error processing customer 650 - name 'phone_col' is not defined
# Warning: Error processing customer 651 - name 'phone_col' is not defined
# Warning: Error processing customer 652 - name 'phone_col' is not defined
# Warning: Error processing customer 653 - name 'phone_col' is not defined
# Warning: Error processing customer 654 - name 'phone_col' is not defined
# Warning: Error processing customer 655 - name 'phone_col' is not defined
# Warning: Error processing customer 656 - name 'phone_col' is not defined
# Warning: Error processing customer 657 - name 'phone_col' is not defined
# Warning: Error processing customer 658 - name 'phone_col' is not defined
# ...
# Warning: Error processing customer 22726 - name 'phone_col' is not defined
# Warning: Error processing customer 22735 - name 'phone_col' is not defined
# Warning: Error processing customer 22739 - name 'phone_col' is not defined
# Warning: Error processing customer 22740 - name 'phone_col' is not defined
# Warning: Error processing customer 22747 - name 'phone_col' is not defined
# Warning: Error processing customer 22753 - name 'phone_col' is not defined
# Warning: Error processing customer 22754 - name 'phone_col' is not defined
# Warning: Error processing customer 22756 - name 'phone_col' is not defined
# Warning: Error processing customer 22758 - name 'phone_col' is not defined
# Warning: Error processing customer 22760 - name 'phone_col' is not defined
# Warning: Error processing customer 22763 - name 'phone_col' is not defined
# Warning: Error processing customer 22764 - name 'phone_col' is not defined
# Warning: Error processing customer 22765 - name 'phone_col' is not defined
# Warning: Error processing customer 22767 - name 'phone_col' is not defined
# Warning: Error processing customer 22768 - name 'phone_col' is not defined
# Warning: Error processing customer 22770 - name 'phone_col' is not defined
# Warning: Error processing customer 22771 - name 'phone_col' is not defined
# Warning: Error processing customer 22773 - name 'phone_col' is not defined
# Warning: Error processing customer 22774 - name 'phone_col' is not defined
# Warning: Error processing customer 22780 - name 'phone_col' is not defined
# Warning: Error processing customer 22783 - name 'phone_col' is not defined
# Warning: Error processing customer 22784 - name 'phone_col' is not defined
# Warning: Error processing customer 22786 - name 'phone_col' is not defined
# Warning: Error processing customer 22789 - name 'phone_col' is not defined
# Warning: Error processing customer 22790 - name 'phone_col' is not defined
# Warning: Error processing customer 22794 - name 'phone_col' is not defined
# Warning: Error processing customer 22799 - name 'phone_col' is not defined
# Warning: Error processing customer 22802 - name 'phone_col' is not defined
# Warning: Error processing customer 22804 - name 'phone_col' is not defined
# Warning: Error processing customer 22805 - name 'phone_col' is not defined
# Warning: Error processing customer 22809 - name 'phone_col' is not defined
# Warning: Error processing customer 22811 - name 'phone_col' is not defined
# Warning: Error processing customer 22813 - name 'phone_col' is not defined
# Warning: Error processing customer 22816 - name 'phone_col' is not defined
# Warning: Error processing customer 22821 - name 'phone_col' is not defined
# Warning: Error processing customer 22823 - name 'phone_col' is not defined
# Warning: Error processing customer 22824 - name 'phone_col' is not defined
# Warning: Error processing customer 22826 - name 'phone_col' is not defined
# Warning: Error processing customer 22834 - name 'phone_col' is not defined
# Warning: Error processing customer 22837 - name 'phone_col' is not defined
# Warning: Error processing customer 22839 - name 'phone_col' is not defined
# Warning: Error processing customer 22840 - name 'phone_col' is not defined
# Warning: Error processing customer 22844 - name 'phone_col' is not defined
# Warning: Error processing customer 22847 - name 'phone_col' is not defined
# Warning: Error processing customer 22850 - name 'phone_col' is not defined
# Warning: Error processing customer 22851 - name 'phone_col' is not defined
# Warning: Error processing customer 22853 - name 'phone_col' is not defined
# Warning: Error processing customer 22854 - name 'phone_col' is not defined
# Warning: Error processing customer 22861 - name 'phone_col' is not defined
# Warning: Error processing customer 22866 - name 'phone_col' is not defined
# Warning: Error processing customer 22868 - name 'phone_col' is not defined
# Warning: Error processing customer 22870 - name 'phone_col' is not defined
# Warning: Error processing customer 22872 - name 'phone_col' is not defined
# Warning: Error processing customer 22873 - name 'phone_col' is not defined
# Warning: Error processing customer 22874 - name 'phone_col' is not defined
# Warning: Error processing customer 22878 - name 'phone_col' is not defined
# Warning: Error processing customer 22882 - name 'phone_col' is not defined
# Warning: Error processing customer 22887 - name 'phone_col' is not defined
# Warning: Error processing customer 22890 - name 'phone_col' is not defined
# Warning: Error processing customer 22894 - name 'phone_col' is not defined
# Warning: Error processing customer 22908 - name 'phone_col' is not defined
# Warning: Error processing customer 22911 - name 'phone_col' is not defined
# Warning: Error processing customer 22915 - name 'phone_col' is not defined
# Warning: Error processing customer 22916 - name 'phone_col' is not defined
# Warning: Error processing customer 22917 - name 'phone_col' is not defined
# Warning: Error processing customer 22927 - name 'phone_col' is not defined
# Warning: Error processing customer 22932 - name 'phone_col' is not defined
# Warning: Error processing customer 22935 - name 'phone_col' is not defined
# Warning: Error processing customer 22939 - name 'phone_col' is not defined
# Warning: Error processing customer 22940 - name 'phone_col' is not defined
# Warning: Error processing customer 22941 - name 'phone_col' is not defined
# Warning: Error processing customer 22946 - name 'phone_col' is not defined
# Warning: Error processing customer 22947 - name 'phone_col' is not defined
# Warning: Error processing customer 22948 - name 'phone_col' is not defined
# Warning: Error processing customer 22951 - name 'phone_col' is not defined
# Warning: Error processing customer 22956 - name 'phone_col' is not defined
# Warning: Error processing customer 22957 - name 'phone_col' is not defined
# Warning: Error processing customer 22960 - name 'phone_col' is not defined
# Warning: Error processing customer 22961 - name 'phone_col' is not defined
# Warning: Error processing customer 22965 - name 'phone_col' is not defined
# Warning: Error processing customer 22968 - name 'phone_col' is not defined
# Warning: Error processing customer 22970 - name 'phone_col' is not defined
# Warning: Error processing customer 22972 - name 'phone_col' is not defined
# Warning: Error processing customer 22974 - name 'phone_col' is not defined
# Warning: Error processing customer 22977 - name 'phone_col' is not defined
# Warning: Error processing customer 22982 - name 'phone_col' is not defined
# Warning: Error processing customer 22985 - name 'phone_col' is not defined
# Warning: Error processing customer 22988 - name 'phone_col' is not defined
# Warning: Error processing customer 22994 - name 'phone_col' is not defined
# Warning: Error processing customer 22996 - name 'phone_col' is not defined
# Warning: Error processing customer 23003 - name 'phone_col' is not defined
# Warning: Error processing customer 23006 - name 'phone_col' is not defined
# Warning: Error processing customer 23007 - name 'phone_col' is not defined
# Warning: Error processing customer 23008 - name 'phone_col' is not defined
# Warning: Error processing customer 23009 - name 'phone_col' is not defined
# Warning: Error processing customer 23022 - name 'phone_col' is not defined
# Warning: Error processing customer 23023 - name 'phone_col' is not defined
# Warning: Error processing customer 23026 - name 'phone_col' is not defined
# Warning: Error processing customer 23030 - name 'phone_col' is not defined
# Warning: Error processing customer 23031 - name 'phone_col' is not defined
# Warning: Error processing customer 23032 - name 'phone_col' is not defined
# Warning: Error processing customer 23034 - name 'phone_col' is not defined
# Warning: Error processing customer 23035 - name 'phone_col' is not defined
# Warning: Error processing customer 23036 - name 'phone_col' is not defined
# Warning: Error processing customer 23040 - name 'phone_col' is not defined
# Warning: Error processing customer 23041 - name 'phone_col' is not defined
# Warning: Error processing customer 23046 - name 'phone_col' is not defined
# Warning: Error processing customer 23051 - name 'phone_col' is not defined
# Warning: Error processing customer 23056 - name 'phone_col' is not defined
# Warning: Error processing customer 23067 - name 'phone_col' is not defined
# Warning: Error processing customer 23069 - name 'phone_col' is not defined
# Warning: Error processing customer 23070 - name 'phone_col' is not defined
# Warning: Error processing customer 23071 - name 'phone_col' is not defined
# Warning: Error processing customer 23072 - name 'phone_col' is not defined
# Warning: Error processing customer 23075 - name 'phone_col' is not defined
# Warning: Error processing customer 23076 - name 'phone_col' is not defined
# Warning: Error processing customer 23078 - name 'phone_col' is not defined
# Warning: Error processing customer 23079 - name 'phone_col' is not defined
# Warning: Error processing customer 23096 - name 'phone_col' is not defined
# Warning: Error processing customer 23105 - name 'phone_col' is not defined
# Warning: Error processing customer 23107 - name 'phone_col' is not defined
# Warning: Error processing customer 23108 - name 'phone_col' is not defined
# Warning: Error processing customer 23110 - name 'phone_col' is not defined
# Warning: Error processing customer 23111 - name 'phone_col' is not defined
# Warning: Error processing customer 23113 - name 'phone_col' is not defined
# Warning: Error processing customer 23114 - name 'phone_col' is not defined
# Warning: Error processing customer 23119 - name 'phone_col' is not defined
# Warning: Error processing customer 23121 - name 'phone_col' is not defined
# Warning: Error processing customer 23124 - name 'phone_col' is not defined
# Warning: Error processing customer 23126 - name 'phone_col' is not defined
# Warning: Error processing customer 23128 - name 'phone_col' is not defined
# Warning: Error processing customer 23130 - name 'phone_col' is not defined
# Warning: Error processing customer 23134 - name 'phone_col' is not defined
# Warning: Error processing customer 23135 - name 'phone_col' is not defined
# Warning: Error processing customer 23142 - name 'phone_col' is not defined
# Warning: Error processing customer 23148 - name 'phone_col' is not defined
# Warning: Error processing customer 23152 - name 'phone_col' is not defined
# Warning: Error processing customer 23153 - name 'phone_col' is not defined
# Warning: Error processing customer 23155 - name 'phone_col' is not defined
# Warning: Error processing customer 23156 - name 'phone_col' is not defined
# Warning: Error processing customer 23167 - name 'phone_col' is not defined
# Warning: Error processing customer 23169 - name 'phone_col' is not defined
# Warning: Error processing customer 23170 - name 'phone_col' is not defined
# Warning: Error processing customer 23172 - name 'phone_col' is not defined
# Warning: Error processing customer 23177 - name 'phone_col' is not defined
# Warning: Error processing customer 23178 - name 'phone_col' is not defined
# Warning: Error processing customer 23182 - name 'phone_col' is not defined
# Warning: Error processing customer 23185 - name 'phone_col' is not defined
# Warning: Error processing customer 23186 - name 'phone_col' is not defined
# Warning: Error processing customer 23188 - name 'phone_col' is not defined
# Warning: Error processing customer 23192 - name 'phone_col' is not defined
# Warning: Error processing customer 23193 - name 'phone_col' is not defined
# Warning: Error processing customer 23199 - name 'phone_col' is not defined
# Warning: Error processing customer 23202 - name 'phone_col' is not defined
# Warning: Error processing customer 23205 - name 'phone_col' is not defined
# Warning: Error processing customer 23206 - name 'phone_col' is not defined
# Warning: Error processing customer 23207 - name 'phone_col' is not defined
# Warning: Error processing customer 23210 - name 'phone_col' is not defined
# Warning: Error processing customer 23215 - name 'phone_col' is not defined
# Warning: Error processing customer 23218 - name 'phone_col' is not defined
# Warning: Error processing customer 23219 - name 'phone_col' is not defined
# Warning: Error processing customer 23222 - name 'phone_col' is not defined
# Warning: Error processing customer 23224 - name 'phone_col' is not defined
# Warning: Error processing customer 23225 - name 'phone_col' is not defined
# Warning: Error processing customer 23228 - name 'phone_col' is not defined
# Warning: Error processing customer 23233 - name 'phone_col' is not defined
# Warning: Error processing customer 23237 - name 'phone_col' is not defined
# Warning: Error processing customer 23238 - name 'phone_col' is not defined
# Warning: Error processing customer 23239 - name 'phone_col' is not defined
# Warning: Error processing customer 23242 - name 'phone_col' is not defined
# Warning: Error processing customer 23245 - name 'phone_col' is not defined
# Warning: Error processing customer 23251 - name 'phone_col' is not defined
# Warning: Error processing customer 23252 - name 'phone_col' is not defined
# Warning: Error processing customer 23254 - name 'phone_col' is not defined
# Warning: Error processing customer 23255 - name 'phone_col' is not defined
# Warning: Error processing customer 23256 - name 'phone_col' is not defined
# Warning: Error processing customer 23260 - name 'phone_col' is not defined
# Warning: Error processing customer 23263 - name 'phone_col' is not defined
# Warning: Error processing customer 23272 - name 'phone_col' is not defined
# Warning: Error processing customer 23277 - name 'phone_col' is not defined
# Warning: Error processing customer 23279 - name 'phone_col' is not defined
# Warning: Error processing customer 23282 - name 'phone_col' is not defined
# Warning: Error processing customer 23287 - name 'phone_col' is not defined
# Warning: Error processing customer 23288 - name 'phone_col' is not defined
# Warning: Error processing customer 23289 - name 'phone_col' is not defined
# Warning: Error processing customer 23292 - name 'phone_col' is not defined
# Warning: Error processing customer 23294 - name 'phone_col' is not defined
# Warning: Error processing customer 23295 - name 'phone_col' is not defined
# Warning: Error processing customer 23299 - name 'phone_col' is not defined
# Warning: Error processing customer 23300 - name 'phone_col' is not defined
# Warning: Error processing customer 23309 - name 'phone_col' is not defined
# Warning: Error processing customer 23310 - name 'phone_col' is not defined
# Warning: Error processing customer 23319 - name 'phone_col' is not defined
# Warning: Error processing customer 23321 - name 'phone_col' is not defined
# Warning: Error processing customer 23325 - name 'phone_col' is not defined
# Warning: Error processing customer 23327 - name 'phone_col' is not defined
# Warning: Error processing customer 23328 - name 'phone_col' is not defined
# Warning: Error processing customer 23330 - name 'phone_col' is not defined
#
# Plan Distribution Analysis:
# --------------------------------------------------
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 171
#     169 print("\nPlan Distribution Analysis:")
#     170 print("-" * 50)
# --> 171 plan_dist = recs_df["plan_name"].value_counts()
#     172 print("\nRecommendations per plan:")
#     173 print(plan_dist)
#
# File c:\Users\look4\anaconda3\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File c:\Users\look4\anaconda3\Lib\site-packages\pandas\core\indexes\range.py:417, in RangeIndex.get_loc(self, key)
#     415         raise KeyError(key) from err
#     416 if isinstance(key, Hashable):
# --> 417     raise KeyError(key)
#     418 self._check_indexing_error(key)
#     419 raise KeyError(key)
#
# KeyError: 'plan_name'

# %%
import joblib, json
from pathlib import Path
OUT_DIR_M = Path(r"C:\Users\look4\Price_Plan_Recommendation\models")
OUT_DIR = Path(r"C:\Users\look4\Price_Plan_Recommendation\data\processed")
OUT_DIR.mkdir(parents=True, exist_ok=True)

# --- Save datasets ---
df.to_csv(OUT_DIR / "customers_with_clusters.csv", index=False)
recs_df.to_csv(OUT_DIR / "top3_recommendations_ph.csv", index=False)
catalog_df.to_csv(OUT_DIR / "plan_catalog.csv", index=False)

print("✅ Datasets saved:")
print(" - customers_with_clusters.csv")
print(" - top3_recommendations.csv")
print(" - plan_catalog.csv")

# --- Save model pipeline ---
model_bundle = {
    "features": features,
    "share_cols": share_cols,
    "scaler": scaler,
    "pca": pca,
    "kmeans": kmeans,
}

MODEL_PATH = OUT_DIR_M / "model.pkl"
joblib.dump(model_bundle, MODEL_PATH)

with open(OUT_DIR / "model_features.json", "w") as f:
    json.dump({"features": features, "share_cols": share_cols}, f, indent=2)

print("✅ Model saved:")
print(" -", MODEL_PATH)
print(" - model_features.json")
# Out:
# ✅ Datasets saved:
#  - customers_with_clusters.csv
#  - top3_recommendations.csv
#  - plan_catalog.csv
# ✅ Model saved:
#  - C:\Users\look4\Price_Plan_Recommendation\models\model.pkl
#  - model_features.json
